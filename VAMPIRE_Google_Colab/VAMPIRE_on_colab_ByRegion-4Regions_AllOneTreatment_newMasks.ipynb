# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
#This allows SDK to see and edit Google Drive files
#SDK is required to interact with GCP
auth.authenticate_user()

# %%
#Get from Drive the folder libraries
# !cp -r /content/drive/MyDrive/SourceCode /content

from SourceCode.mainbody import mainbody
from SourceCode.getboundary import getboundary

# %%
import csv
import ntpath
import re
import os
import numpy as np
import pickle
from skimage.io import imread, imsave, imshow

# %% [markdown]
# # Copy segmented, labeled images from GCP to local directory

# %%
treatment_path = 'cellmbucket/analysis/controls_paths_11222021.txt' #@param {type:"string"}

#read treatment locations file
# !gsutil cp gs://{treatment_path} ./
treatment_file = ntpath.basename(treatment_path)
treatment_obj = open(treatment_file, "r")
treatment_locs = treatment_obj.readlines()
# Out:
# Copying gs://cellmbucket/analysis/controls_paths_11222021.txt...
# / [1 files][  1.1 KiB/  1.1 KiB]
# Operation completed over 1 objects/1.1 KiB.

# %%
treatment_locs
# Out:
# ['controls\n',
#  'cellmbucket/analysis_042221/06032020-JR20-control\n',
#  'cellmbucket/analysis_pri_050521/03122021-JR20P14-control-sample5\n',
#  'cellmbucket/analysis_pri_050521/03122021-JR20P14-control\n',
#  'cellmbucket/analysis_sam_042821/031521_control_sample3\n',
#  'cellmbucket/analysis_sam_042821/031521_control_sample4\n',
#  'cellmbucket/analysis_sam_042821/031521_control_sample5\n',
#  '\n',
#  'cellmbucket/analysis_eliz_05042021/trial1/05042021_ARPC2_KO_sample6\n',
#  'cellmbucket/analysis_eliz_05042021/trial3/05112021_ARPC2_KO_sample3\n',
#  'cellmbucket/analysis_eliz_05042021/trial4/05202021_ARPC2_KO_sample4\n',
#  'cellmbucket/analysis_eliz_05042021/trial5/060622021_ARPC2_KO_sample3\n',
#  '\n',
#  'cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_sample3\n',
#  'cellmbucket/analysis_eliz_05262021/trial2/052822021_Fascin_KO_sample3\n',
#  'cellmbucket/analysis_eliz_05262021/trial3/060222021_Fascin_KO_sample3\n',
#  '\n',
#  'cellmbucket/analysis_eliz_09162021/09162021\n',
#  '\n',
#  'cellmbucket/analysis_eliz_062719/controls_2019_062719_sample1\n',
#  'cellmbucket/analysis_eliz_062719/controls_2019_062719_sample2\n',
#  'cellmbucket/analysis_sam_062819/controls_2019_062819_sample1\n',
#  'cellmbucket/analysis_sam_062819/controls_2019_062819_sample2']

# %%
#get all files full paths. Some data has the same name but is stored in different folder
file_paths = []
#tracks_shape_file_paths = []
for i in range(1,len(treatment_locs)):
  if len(treatment_locs[i].strip("\n")) > 0: #if line contains data
    file_paths.append(treatment_locs[i].strip("\n"))
    #tracks_shape_file_paths.append(treatment_locs[i].strip("\n")+'_tracks_shape')

# %%
file_paths
# Out:
# ['cellmbucket/analysis_042221/06032020-JR20-control',
#  'cellmbucket/analysis_pri_050521/03122021-JR20P14-control-sample5',
#  'cellmbucket/analysis_pri_050521/03122021-JR20P14-control',
#  'cellmbucket/analysis_sam_042821/031521_control_sample3',
#  'cellmbucket/analysis_sam_042821/031521_control_sample4',
#  'cellmbucket/analysis_sam_042821/031521_control_sample5',
#  'cellmbucket/analysis_eliz_05042021/trial1/05042021_ARPC2_KO_sample6',
#  'cellmbucket/analysis_eliz_05042021/trial3/05112021_ARPC2_KO_sample3',
#  'cellmbucket/analysis_eliz_05042021/trial4/05202021_ARPC2_KO_sample4',
#  'cellmbucket/analysis_eliz_05042021/trial5/060622021_ARPC2_KO_sample3',
#  'cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_sample3',
#  'cellmbucket/analysis_eliz_05262021/trial2/052822021_Fascin_KO_sample3',
#  'cellmbucket/analysis_eliz_05262021/trial3/060222021_Fascin_KO_sample3',
#  'cellmbucket/analysis_eliz_09162021/09162021',
#  'cellmbucket/analysis_eliz_062719/controls_2019_062719_sample1',
#  'cellmbucket/analysis_eliz_062719/controls_2019_062719_sample2',
#  'cellmbucket/analysis_sam_062819/controls_2019_062819_sample1',
#  'cellmbucket/analysis_sam_062819/controls_2019_062819_sample2']

# %%
for maskspath in file_paths:
  # !gsutil cp gs://{maskspath}_tracks_masks.zip ./
  folder_loc = ntpath.basename(maskspath)
  folderimages = folder_loc + '_tracks_masks'
  # !unzip {folderimages}.zip

  # !gsutil cp gs://{maskspath}_tracks_shape.pkl ./
  with open('/content/' + folder_loc + '_tracks_shape.pkl', 'rb') as handle:
            tracksshape = pickle.load(handle, encoding='latin1')

  #use tracksshape to save individual tiff files from tiff stacks according to the region they correspond to into a folder labeled by that region
  names_movies=[f for f in os.listdir(folderimages) if f.endswith('.TIF')]

  for region in ['stiff', 'gradient1', 'gradient2', 'soft', 'newsteep']:
    if os.path.exists('/content/' + region) == False:
      # !mkdir {region}
    for i in range(len(tracksshape)):
      if tracksshape[i]['gel-region'].str.contains(region).any():
        trackid = tracksshape[i]['track_id'].loc[0]
        movieid = int(tracksshape[i]['movie'].loc[0])
        for name in names_movies:
          if '_track' + trackid + '.TIF' in name:
            movie=imread(folderimages+'/'+name)
            name=name.strip('.TIF')
            for i in range(movie.shape[0]):
              imagename = name + '_' + region + '_movie' + str(movieid) + '_t'+str(i+1)+'.TIF'
              imsave(region + '/' + imagename, movie[i])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##Save images separated by region on GCS

# %%
#@markdown Date of running this analysis and image description (will be included in the zip file name of the separated images by region)
descriptor = '01052022_controls' #@param {type:"string"}

# %%
# !zip -r {descriptor}_controls_4regions_masksbytrack.zip soft gradient1 gradient2 stiff newsteep
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: stiff/controls_2019_062819_sample2_track4_stiff_movie4_t20.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track6_stiff_movie6_t14.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track8_stiff_movie6_t9.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t6.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t53.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t7.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track4_stiff_movie2_t14.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track5_stiff_movie5_t9.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track9_stiff_movie8_t6.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t64.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t36.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track10_stiff_movie5_t16.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t21.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track8_stiff_movie8_t17.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t93.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t21.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t1.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track2_stiff_movie3_t20.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t18.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track6_stiff_movie7_t2.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t17.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t65.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t27.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t117.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track4_stiff_movie5_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t57.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t114.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t72.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t8.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track0_stiff_movie1_t26.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t3.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track2_stiff_movie4_t34.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t26.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t7.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track8_stiff_movie7_t32.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t22.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t68.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t9.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track0_stiff_movie1_t20.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t78.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t5.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track5_stiff_movie6_t43.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track2_stiff_movie4_t8.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t105.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track10_stiff_movie9_t1.TIF (deflated 100%)
#   adding: stiff/09162021_track3_stiff_movie4_t2.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track4_stiff_movie4_t15.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t26.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t20.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t28.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t26.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t80.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t43.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t87.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t83.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t46.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track9_stiff_movie5_t19.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track2_stiff_movie2_t29.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track4_stiff_movie4_t11.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t21.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t104.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t118.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t19.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t29.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t120.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t20.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t13.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t30.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t111.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t12.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track2_stiff_movie2_t15.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t28.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t94.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t28.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track7_stiff_movie6_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track2_stiff_movie1_t18.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t27.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t20.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t41.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t72.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t66.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t103.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track1_stiff_movie1_t1.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track2_stiff_movie2_t5.TIF (deflated 100%)
#   adding: stiff/09162021_track1_stiff_movie2_t14.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t89.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t37.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t45.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track2_stiff_movie2_t32.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track5_stiff_movie5_t20.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track7_stiff_movie7_t22.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track6_stiff_movie7_t6.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track7_stiff_movie7_t64.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track1_stiff_movie1_t49.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t15.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track2_stiff_movie3_t6.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t72.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t29.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t22.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track8_stiff_movie7_t47.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track1_stiff_movie1_t2.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t15.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track2_stiff_movie3_t62.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t20.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track8_stiff_movie5_t7.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t13.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track8_stiff_movie8_t24.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t17.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track1_stiff_movie2_t46.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t114.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t11.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t9.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t2.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t42.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track3_stiff_movie3_t4.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t101.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t80.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track0_stiff_movie1_t69.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track4_stiff_movie2_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t81.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track4_stiff_movie2_t14.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t40.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track7_stiff_movie6_t20.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track7_stiff_movie7_t53.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t50.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t30.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track3_stiff_movie4_t6.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t8.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t61.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t7.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track7_stiff_movie6_t17.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track5_stiff_movie6_t12.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track2_stiff_movie2_t3.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track2_stiff_movie3_t32.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t145.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track7_stiff_movie6_t18.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t82.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track8_stiff_movie7_t21.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t19.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t72.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t22.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t4.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t105.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t5.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t16.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t19.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track6_stiff_movie6_t46.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track7_stiff_movie5_t5.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t110.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t26.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t115.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track4_stiff_movie5_t10.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track3_stiff_movie3_t10.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track5_stiff_movie4_t1.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track4_stiff_movie4_t31.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t43.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track8_stiff_movie6_t23.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track2_stiff_movie3_t28.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track5_stiff_movie3_t41.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t10.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t50.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track6_stiff_movie4_t13.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track15_stiff_movie7_t14.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t34.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track0_stiff_movie1_t23.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t18.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t16.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t82.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t114.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t60.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t29.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t40.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track6_stiff_movie6_t77.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t12.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track5_stiff_movie4_t9.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t31.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t74.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t41.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t20.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t65.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track12_stiff_movie6_t3.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track1_stiff_movie2_t19.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t51.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t32.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track8_stiff_movie8_t28.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t24.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track10_stiff_movie6_t11.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t23.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track0_stiff_movie1_t42.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t53.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t24.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track2_stiff_movie2_t2.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t16.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track7_stiff_movie6_t10.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track1_stiff_movie1_t6.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t48.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track8_stiff_movie6_t22.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t11.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t54.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t29.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t67.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t10.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t89.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t4.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t3.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t68.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track3_stiff_movie3_t16.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t3.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track9_stiff_movie8_t14.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t22.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track6_stiff_movie7_t23.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track5_stiff_movie3_t32.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t33.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track0_stiff_movie1_t15.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track9_stiff_movie8_t15.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t78.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track0_stiff_movie1_t3.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track11_stiff_movie7_t25.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track7_stiff_movie6_t10.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t14.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t27.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t174.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t65.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track5_stiff_movie4_t52.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track4_stiff_movie2_t42.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t29.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track5_stiff_movie6_t18.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track5_stiff_movie6_t14.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t44.TIF (deflated 100%)
#   adding: stiff/09162021_track0_stiff_movie1_t24.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track6_stiff_movie7_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t26.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track0_stiff_movie1_t17.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t29.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t86.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t15.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track8_stiff_movie5_t47.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track1_stiff_movie2_t15.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track3_stiff_movie3_t33.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t72.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t129.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track1_stiff_movie2_t23.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track5_stiff_movie5_t51.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t100.TIF (deflated 100%)
#   adding: stiff/09162021_track3_stiff_movie4_t5.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t88.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t3.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track2_stiff_movie1_t33.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t3.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t60.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track5_stiff_movie5_t8.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t75.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track7_stiff_movie7_t28.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track3_stiff_movie3_t3.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track5_stiff_movie6_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t31.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track8_stiff_movie5_t8.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t10.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t26.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t167.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t150.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track7_stiff_movie5_t18.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track6_stiff_movie4_t21.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track5_stiff_movie6_t7.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t45.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t12.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t37.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track5_stiff_movie6_t43.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t57.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track3_stiff_movie2_t30.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track10_stiff_movie5_t3.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t38.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t64.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track2_stiff_movie3_t1.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t41.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track5_stiff_movie6_t33.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t135.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t7.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track2_stiff_movie4_t17.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t41.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track8_stiff_movie7_t13.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t44.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t45.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track5_stiff_movie4_t16.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track2_stiff_movie3_t11.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t33.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t108.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track5_stiff_movie4_t26.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t10.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t115.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track0_stiff_movie1_t20.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track5_stiff_movie3_t37.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track2_stiff_movie3_t24.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track5_stiff_movie5_t13.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track7_stiff_movie7_t17.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t126.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t47.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track0_stiff_movie1_t1.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t22.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t159.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track4_stiff_movie2_t7.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t53.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track7_stiff_movie7_t46.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track12_stiff_movie6_t7.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t16.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track2_stiff_movie2_t14.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track2_stiff_movie2_t3.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t17.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t118.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track3_stiff_movie2_t39.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track0_stiff_movie1_t3.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track5_stiff_movie5_t34.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t95.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t77.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track3_stiff_movie3_t15.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track1_stiff_movie2_t11.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track4_stiff_movie4_t3.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t71.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track10_stiff_movie9_t2.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track12_stiff_movie12_t11.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track4_stiff_movie5_t1.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track5_stiff_movie6_t16.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t30.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track4_stiff_movie4_t5.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t61.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track0_stiff_movie1_t13.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track5_stiff_movie5_t19.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track7_stiff_movie7_t11.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track2_stiff_movie3_t67.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track7_stiff_movie7_t27.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track7_stiff_movie7_t54.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track4_stiff_movie5_t8.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track1_stiff_movie2_t33.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t15.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track7_stiff_movie7_t9.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t7.TIF (deflated 100%)
#   adding: stiff/09162021_track0_stiff_movie1_t6.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t21.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t24.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track3_stiff_movie3_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track1_stiff_movie1_t45.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t120.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t31.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t25.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track7_stiff_movie7_t9.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t157.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t7.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t2.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track0_stiff_movie1_t12.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t64.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track11_stiff_movie7_t30.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track0_stiff_movie1_t29.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track0_stiff_movie1_t17.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track3_stiff_movie1_t18.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track7_stiff_movie7_t30.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track8_stiff_movie7_t39.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track0_stiff_movie1_t2.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t17.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track3_stiff_movie4_t51.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t126.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t18.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track5_stiff_movie5_t30.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track0_stiff_movie1_t7.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track8_stiff_movie7_t5.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t32.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track3_stiff_movie4_t31.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t42.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track8_stiff_movie8_t31.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track3_stiff_movie2_t1.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track3_stiff_movie1_t14.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track6_stiff_movie6_t10.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track3_stiff_movie3_t1.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t66.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t26.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track0_stiff_movie1_t43.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t38.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t88.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t59.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track7_stiff_movie7_t30.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t83.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t105.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t23.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track10_stiff_movie6_t2.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t48.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track0_stiff_movie1_t36.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track0_stiff_movie1_t25.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t99.TIF (deflated 100%)
#   adding: stiff/09162021_track5_stiff_movie6_t1.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t28.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track2_stiff_movie3_t33.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track2_stiff_movie1_t13.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t34.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track5_stiff_movie6_t36.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t36.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t12.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track3_stiff_movie3_t31.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track5_stiff_movie5_t106.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track7_stiff_movie7_t14.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t10.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t7.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t20.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t24.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track2_stiff_movie2_t9.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t101.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t62.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t69.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track3_stiff_movie4_t62.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track5_stiff_movie5_t11.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t54.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track4_stiff_movie4_t1.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t133.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t39.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t12.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t19.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t72.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track8_stiff_movie8_t29.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track10_stiff_movie6_t9.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track5_stiff_movie5_t24.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t44.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t106.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track8_stiff_movie8_t8.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t122.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t66.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track8_stiff_movie5_t11.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track8_stiff_movie8_t35.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track16_stiff_movie8_t4.TIF (deflated 100%)
#   adding: stiff/09162021_track0_stiff_movie1_t12.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track6_stiff_movie4_t12.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track1_stiff_movie1_t4.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track0_stiff_movie1_t9.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t11.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t45.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track4_stiff_movie4_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t67.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track8_stiff_movie7_t47.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t79.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t8.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t17.TIF (deflated 100%)
#   adding: stiff/09162021_track2_stiff_movie3_t10.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t96.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t4.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t67.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track6_stiff_movie6_t11.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track4_stiff_movie4_t4.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t128.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t91.TIF (deflated 100%)
#   adding: stiff/09162021_track4_stiff_movie5_t36.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track8_stiff_movie4_t23.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t1.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track2_stiff_movie2_t5.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track6_stiff_movie4_t5.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t47.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track5_stiff_movie6_t57.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track3_stiff_movie5_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t43.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track4_stiff_movie5_t23.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track8_stiff_movie6_t29.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t96.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t23.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t95.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t48.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track5_stiff_movie4_t14.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t12.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t66.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t30.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track2_stiff_movie4_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t51.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track6_stiff_movie6_t5.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t63.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t63.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track3_stiff_movie3_t59.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track6_stiff_movie4_t6.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t117.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t14.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track5_stiff_movie3_t53.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t12.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t55.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track4_stiff_movie5_t22.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t5.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t9.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track0_stiff_movie1_t11.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track2_stiff_movie2_t11.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t15.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track0_stiff_movie1_t5.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t53.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t65.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track8_stiff_movie7_t1.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track3_stiff_movie4_t13.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track1_stiff_movie1_t10.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track2_stiff_movie3_t5.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t16.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t17.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track6_stiff_movie6_t74.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track1_stiff_movie2_t27.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t38.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t13.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track7_stiff_movie4_t13.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t90.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t5.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t27.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track1_stiff_movie2_t36.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t66.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t44.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track1_stiff_movie1_t2.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t44.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t44.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track6_stiff_movie6_t16.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track2_stiff_movie3_t27.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t30.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t58.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track0_stiff_movie1_t21.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t21.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track7_stiff_movie5_t14.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t23.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t38.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track2_stiff_movie1_t41.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t102.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track1_stiff_movie2_t26.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track2_stiff_movie2_t10.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t78.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track2_stiff_movie1_t7.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t39.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track12_stiff_movie12_t12.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t103.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track8_stiff_movie7_t11.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t109.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track5_stiff_movie5_t98.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track9_stiff_movie8_t1.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t9.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t16.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track8_stiff_movie5_t3.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t116.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t61.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t43.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t30.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track7_stiff_movie7_t66.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t6.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track8_stiff_movie8_t9.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t41.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track5_stiff_movie4_t4.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t1.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t64.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t87.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track6_stiff_movie6_t3.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track3_stiff_movie3_t23.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track4_stiff_movie4_t3.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t12.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t40.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t60.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track6_stiff_movie7_t3.TIF (deflated 100%)
# ...
#   adding: stiff/03122021-JR20P14-control_track4_stiff_movie4_t19.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t57.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track2_stiff_movie3_t18.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t76.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t90.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t102.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t28.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t46.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track1_stiff_movie2_t20.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t8.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track0_stiff_movie1_t23.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track7_stiff_movie6_t2.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track8_stiff_movie7_t44.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t16.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track2_stiff_movie1_t47.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track13_stiff_movie7_t5.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t44.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track11_stiff_movie11_t53.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t148.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t35.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track8_stiff_movie6_t20.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t51.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t100.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track4_stiff_movie5_t17.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track5_stiff_movie3_t50.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t52.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track2_stiff_movie1_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t67.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track3_stiff_movie4_t57.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t116.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t122.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t15.TIF (deflated 100%)
#   adding: stiff/09162021_track4_stiff_movie5_t20.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track8_stiff_movie6_t27.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t44.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t69.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track8_stiff_movie6_t4.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track2_stiff_movie2_t2.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t59.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t119.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track2_stiff_movie3_t10.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track0_stiff_movie1_t40.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t37.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track6_stiff_movie6_t7.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t27.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track13_stiff_movie7_t26.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t48.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track5_stiff_movie5_t25.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t14.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t38.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t66.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track2_stiff_movie1_t7.TIF (deflated 100%)
#   adding: stiff/09162021_track0_stiff_movie1_t14.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track8_stiff_movie5_t20.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t85.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track7_stiff_movie7_t18.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t57.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track8_stiff_movie8_t26.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t8.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t37.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track3_stiff_movie4_t40.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track15_stiff_movie7_t12.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track4_stiff_movie2_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t44.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t134.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t7.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track9_stiff_movie6_t3.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track1_stiff_movie2_t35.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t17.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track2_stiff_movie2_t35.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track6_stiff_movie6_t23.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t49.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track4_stiff_movie4_t32.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track6_stiff_movie4_t9.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track1_stiff_movie2_t2.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t45.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track6_stiff_movie6_t29.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track6_stiff_movie4_t70.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t13.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t132.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track0_stiff_movie1_t177.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t20.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t18.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track7_stiff_movie7_t58.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track2_stiff_movie3_t71.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track3_stiff_movie1_t6.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t46.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t54.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track8_stiff_movie7_t48.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track1_stiff_movie1_t34.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t75.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t9.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track16_stiff_movie8_t7.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t156.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t60.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t88.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t175.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t67.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track1_stiff_movie2_t4.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track12_stiff_movie12_t16.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track0_stiff_movie1_t13.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t55.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track2_stiff_movie2_t15.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track2_stiff_movie4_t14.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t7.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track8_stiff_movie7_t19.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t20.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t36.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t49.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track0_stiff_movie1_t40.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track4_stiff_movie3_t110.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track2_stiff_movie3_t12.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track3_stiff_movie3_t8.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t84.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t20.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track7_stiff_movie7_t35.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t37.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track0_stiff_movie1_t20.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track3_stiff_movie3_t20.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track5_stiff_movie5_t12.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track6_stiff_movie6_t62.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track1_stiff_movie1_t17.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track2_stiff_movie3_t36.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track0_stiff_movie1_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t63.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track0_stiff_movie1_t77.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t87.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track0_stiff_movie1_t59.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t25.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track1_stiff_movie2_t1.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t19.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track6_stiff_movie5_t1.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t12.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track5_stiff_movie3_t30.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track7_stiff_movie7_t26.TIF (deflated 100%)
#   adding: stiff/031521_control_sample3_track0_stiff_movie1_t9.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t138.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track0_stiff_movie1_t32.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track5_stiff_movie6_t55.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track2_stiff_movie2_t8.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track5_stiff_movie5_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track5_stiff_movie3_t62.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t60.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track4_stiff_movie4_t6.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t22.TIF (deflated 100%)
#   adding: stiff/052822021_Fascin_KO_sample3_track1_stiff_movie2_t87.TIF (deflated 100%)
#   adding: stiff/06032020-JR20-control_track10_stiff_movie5_t11.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t25.TIF (deflated 100%)
#   adding: stiff/031521_control_sample4_track2_stiff_movie3_t21.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track1_stiff_movie1_t14.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track4_stiff_movie5_t133.TIF (deflated 100%)
#   adding: stiff/05042021_ARPC2_KO_sample6_track4_stiff_movie3_t45.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track5_stiff_movie5_t21.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track7_stiff_movie6_t20.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track1_stiff_movie2_t95.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track7_stiff_movie7_t24.TIF (deflated 100%)
#   adding: stiff/060222021_Fascin_KO_sample3_track3_stiff_movie4_t136.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t49.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track6_stiff_movie6_t51.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track2_stiff_movie3_t65.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t32.TIF (deflated 100%)
#   adding: stiff/031521_control_sample5_track2_stiff_movie4_t30.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track6_stiff_movie6_t32.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t50.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track5_stiff_movie4_t27.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track3_stiff_movie4_t40.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t35.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track5_stiff_movie5_t23.TIF (deflated 100%)
#   adding: stiff/052622021_Fascin_KO_sample3_track0_stiff_movie1_t6.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track3_stiff_movie3_t14.TIF (deflated 100%)
#   adding: stiff/09162021_track1_stiff_movie2_t3.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track7_stiff_movie8_t51.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control-sample5_track0_stiff_movie1_t35.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample1_track10_stiff_movie6_t18.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track3_stiff_movie3_t106.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample1_track5_stiff_movie5_t92.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t22.TIF (deflated 100%)
#   adding: stiff/05112021_ARPC2_KO_sample3_track8_stiff_movie8_t33.TIF (deflated 100%)
#   adding: stiff/05202021_ARPC2_KO_sample4_track5_stiff_movie6_t5.TIF (deflated 100%)
#   adding: stiff/controls_2019_062719_sample2_track5_stiff_movie3_t65.TIF (deflated 100%)
#   adding: stiff/controls_2019_062819_sample2_track2_stiff_movie2_t63.TIF (deflated 100%)
#   adding: stiff/03122021-JR20P14-control_track2_stiff_movie2_t117.TIF (deflated 100%)
#   adding: stiff/060622021_ARPC2_KO_sample3_track3_stiff_movie3_t10.TIF (deflated 100%)
#   adding: newsteep/ (stored 0%)

# %%
# !gsutil cp /content/{descriptor}_controls_4regions_masksbytrack.zip gs://cellmbucket/analysis
# Out:
# Copying file:///content/01052022_controls_controls_4regions_masksbytrack.zip [Content-Type=application/zip]...
# -
# Operation completed over 1 objects/9.6 MiB.

# %% [markdown]
# # Make csv file that contains paths to segmented, labeled images in local directory with descriptions for each set

# %%
csv_fields=['set ID', 'condition', 'set location', 'tag', 'note']

# %%
#@markdown Parameters for the csv that indicate where the masks are located

#@markdown Row index number
setID1 = '1' #@param {type:"string"}
setID2 = '2' #@param {type:"string"}
setID3 = '3' #@param {type:"string"}
setID4 = '4' #@param {type:"string"}
#@markdown Description of an image set
condition1 = 'stiff' #@param {type:"string"}
condition2 = 'gradient1' #@param {type:"string"}
condition3 = 'gradient2' #@param {type:"string"}
condition4 = 'soft' #@param {type:"string"}
#@markdown The path of the folder containing the segmented images
set_location1 = '/content/stiff' #@param {type:"string"}
set_location2 = '/content/gradient1' #@param {type:"string"}
set_location3 = '/content/gradient2' #@param {type:"string"}
set_location4 = '/content/soft' #@param {type:"string"}
#@markdown String of text where only segmented images in the set location with filenames containing the tag will be analyzed
tag1 = 'track' #@param {type:"string"}
tag2 = 'track' #@param {type:"string"}
tag3 = 'track' #@param {type:"string"}
tag4 = 'track' #@param {type:"string"}
#@markdown Any information about the image sets used only for the user's record. This is not used in the analysis
note1 = 'all_controls' #@param {type:"string"}
note2 = 'all_controls' #@param {type:"string"}
note3 = 'all_controls' #@param {type:"string"}
note4 = 'all_controls' #@param {type:"string"}
#@markdown Name of the csv file that is created
csv_name = 'segmented_image_sets_to_build_model_colab' #@param {type:"string"}

# %%
rows=[[setID1,
  condition1,
  set_location1,
  tag1,
  note1],
 [setID2,
  condition2,
  set_location2,
  tag2,
  note2],
  [setID3,
  condition3,
  set_location3,
  tag3,
  note3],
  [setID4,
  condition4,
  set_location4,
  tag4,
  note4]]

# %%
csv_filename = '/content/' + csv_name + '.csv'

# %%
with open(csv_filename, 'w') as csvfile:
    # creating a csv writer object
    csvwriter = csv.writer(csvfile)
      
    # writing the fields
    csvwriter.writerow(csv_fields)
      
    # writing the data rows
    csvwriter.writerows(rows)

# %% [markdown]
# # Specify VAMPIRE model parameters

# %%
entries={}

# %%
fields = (
        'Build Model', 'Image sets to build', 'Number of coordinates', 'Number of principal components', 'Number of shape modes', 'Model output folder',
        'Model name', 'Image sets to apply', 'Model to apply', 'Result output folder')

# %%
#@markdown Parameters for VAMPIRE model

#@markdown Build model (True or False)
Build_Model = False #@param {type:"boolean"}
#@markdown Path to csv file to load that contains path to masks
Image_sets_to_build = '/content/segmented_image_sets_to_build_model_colab.csv' #@param {type:"string"}
#@markdown Number of coordinates used to describe cell shape
Number_of_coordinates = '10' #@param {type:"string"}
#@markdown Number of principal components to use for PCA
pcnum = '10' #@param {type:"string"}
#@markdown Number of clusters to form to describe cell shapes
Number_of_shape_modes = '10' #@param {type:"string"}
#@markdown Path to location where output data is saved
Model_output_folder = '/content' #@param {type:"string"}
#@markdown Name of folder where output will be saved (and name of the model pickle file)
Model_name = '400Coords10PC10ShapeModes_4Regions_controls' #@param {type:"string"}
#@markdown Apply model

#@markdown Only complete the below entries if you are applying the model

#@markdown Path to csv file to load that contains path to masks
Image_sets_to_apply = '/content/segmented_image_sets_to_build_model_colab.csv' #@param {type:"string"}
#@markdown Path to pickle model file 
Model_to_apply = '/content/400Coords10PC10ShapeModes_4Regions_controls/400Coords10PC10ShapeModes_4Regions_controls.pickle' #@param {type:"string"}
#@markdown Path to location where outpur data is saved (usually the folder that was created with Build Model)
Result_output_folder = '/content/400Coords10PC10ShapeModes_4Regions_controls' #@param {type:"string"}

# %%
ents = [Build_Model, Image_sets_to_build, Number_of_coordinates, pcnum, Number_of_shape_modes, Model_output_folder, Model_name, Image_sets_to_apply, Model_to_apply, Result_output_folder]

for count,field in enumerate(fields):
  entries[field] = ents[count]

# %%
# Make folders in local directory where figures and model pickle file will be saved 

if Build_Model:
  foldername = Model_output_folder + '/' + Model_name
  # !mkdir {foldername}
  newfolder = foldername + '/' + 'Example model figures'
  # !mkdir '{newfolder}'
else:
  foldername = Result_output_folder + '/' + 'Result based on ' + ntpath.basename(Result_output_folder)
  # !mkdir '{foldername}'

# %%
entries
# Out:
# {'Build Model': False,
#  'Image sets to apply': '/content/segmented_image_sets_to_build_model_colab.csv',
#  'Image sets to build': '/content/segmented_image_sets_to_build_model_colab.csv',
#  'Model name': '400Coords10PC10ShapeModes_4Regions_controls',
#  'Model output folder': '/content',
#  'Model to apply': '/content/400Coords10PC10ShapeModes_4Regions_controls/400Coords10PC10ShapeModes_4Regions_controls.pickle',
#  'Number of coordinates': '10',
#  'Number of principal components': '10',
#  'Number of shape modes': '10',
#  'Result output folder': '/content/400Coords10PC10ShapeModes_4Regions_controls'}

# %%
def Model(entries, buildModel):
    if buildModel:
        csv = entries['Image sets to build']
        clnum = entries['Number of shape modes']
        outpth = entries['Model output folder']  # name
        getboundary(csv, outpth, entries, buildModel)  # create registry csv and boundary stack
        mainbody(buildModel, csv, entries, outpth, clnum)
    else:
        csv = entries['Image sets to apply']
        outpth = entries['Result output folder']
        clnum = None
        getboundary(csv, outpth, entries, buildModel)  # create registry csv and boundary stack
        mainbody(buildModel, csv, entries, outpth, clnum)


def vampire():
    Model(entries, Build_Model)

# %% [markdown]
# # Run the VAMPIRE analysis

# %%
vampire()
# Out:
# ## getboundary.py
# registry or boundary already exist
# registry or boundary already exist
# registry or boundary already exist
# registry or boundary already exist
# ## main.py
# ## bdreg.py
# applying model
# available cpu cores :  2
# For parallel of bdreg, elapsed time is 12.303724527359009seconds...
# ## pca_bdreg.py
# For PCA bdreg, elapsed time is 0.020613431930541992seconds...
# # clusterSM
# For cluster, elapsed time is 1.6349983215332031seconds...
# ## update_csv.py
# ## bdreg.py
# applying model
# available cpu cores :  2
# For parallel of bdreg, elapsed time is 10.603606462478638seconds...
# ## pca_bdreg.py
# For PCA bdreg, elapsed time is 0.007773399353027344seconds...
# # clusterSM
# For cluster, elapsed time is 1.1159672737121582seconds...
# ## update_csv.py
# ## bdreg.py
# applying model
# available cpu cores :  2
# For parallel of bdreg, elapsed time is 10.229724168777466seconds...
# ## pca_bdreg.py
# For PCA bdreg, elapsed time is 0.004550457000732422seconds...
# # clusterSM
# For cluster, elapsed time is 1.0978868007659912seconds...
# ## update_csv.py
# ## bdreg.py
# applying model
# available cpu cores :  2
# For parallel of bdreg, elapsed time is 7.017038106918335seconds...
# ## pca_bdreg.py
# For PCA bdreg, elapsed time is 0.0030329227447509766seconds...
# # clusterSM
# For cluster, elapsed time is 1.0471553802490234seconds...
# ## update_csv.py

# %% [markdown]
# # Copy files generated from VAMPIRE analysis (csv files of shape features, model pickle file, pickle files of boundary coordinates, and figures) to GCP bucket

# %%
#@markdown Where to save VAMPIRE files in GCP bucket
GCP_path = 'cellmbucket/VAMPIRE_analysis/all_controls' #@param {type:"string"}
#@markdown Name of folder that will contain all generated files from the VAMPIRE analysis in GCP bucket
output_folder = '01242022' #@param {type:"string"}

# %%
output_data = Model_output_folder + '/' + Model_name

output_path = GCP_path + '/' + output_folder + '/'

# !gsutil cp -r '{output_data}'  gs://{output_path}
# Out:
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/stiff_boundary_coordinate_stack.pickle [Content-Type=application/octet-stream]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/soft_boundary_coordinate_stack.pickle [Content-Type=application/octet-stream]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/VAMPIRE datasheet gradient1.csv [Content-Type=text/csv]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/400Coords10PC10ShapeModes_4Regions_controls.pickle [Content-Type=application/octet-stream]...
# \ [4 files][ 29.6 MiB/ 29.6 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/gradient2_boundary_coordinate_stack.pickle [Content-Type=application/octet-stream]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/VAMPIRE datasheet gradient2.csv [Content-Type=text/csv]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/VAMPIRE datasheet stiff.csv [Content-Type=text/csv]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/gradient1_boundary_coordinate_stack.pickle [Content-Type=application/octet-stream]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/VAMPIRE datasheet soft.csv [Content-Type=text/csv]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/Example model figures/Shape mode dendrogram.png [Content-Type=image/png]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/Example model figures/Registered objects.png [Content-Type=image/png]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/Result based on 400Coords10PC10ShapeModes_4Regions_controls/Shape mode distribution_1_stiff.png [Content-Type=image/png]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/Result based on 400Coords10PC10ShapeModes_4Regions_controls/Shape mode distribution_3_gradient2.png [Content-Type=image/png]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/Result based on 400Coords10PC10ShapeModes_4Regions_controls/Shape mode distribution_2_gradient1.png [Content-Type=image/png]...
# Copying file:///content/400Coords10PC10ShapeModes_4Regions_controls/Result based on 400Coords10PC10ShapeModes_4Regions_controls/Shape mode distribution_4_soft.png [Content-Type=image/png]...
# |
# Operation completed over 15 objects/70.5 MiB.

# %% [markdown]
# ## This is just code to copy things from google cloud bucket to here to zip and download locally

# %%
# !gsutil cp -r gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4 ./
# Out:
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/50Coords10ShapeModes_AllRegionsSample4.pickle...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/Example model figures/Registered objects.png...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/Example model figures/Shape mode dendrogram.png...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_1_stiff.png...
# - [4 files][  1.4 MiB/  1.4 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_2_steep1.png...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_3_steep2.png...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_4_soft.png...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet soft.csv...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet steep1.csv...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet steep2.csv...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet stiff.csv...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/soft_boundary_coordinate_stack.pickle...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/steep1_boundary_coordinate_stack.pickle...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/steep2_boundary_coordinate_stack.pickle...
# Copying gs://cellmbucket/analysis_eliz_05262021/trial1/052622021_Fascin_KO_VAMPIRE_analysis/50Coords10ShapeModes_AllRegionsSample4/stiff_boundary_coordinate_stack.pickle...
# / [15 files][  5.3 MiB/  5.3 MiB]
# Operation completed over 15 objects/5.3 MiB.

# %%
# !zip -r "/content/50Coords10ShapeModes_AllRegionsSample4.zip" "/content/50Coords10ShapeModes_AllRegionsSample4"
# Out:
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/ (stored 0%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/stiff_boundary_coordinate_stack.pickle (deflated 90%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/ (stored 0%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_3_steep2.png (deflated 9%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_2_steep1.png (deflated 8%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_4_soft.png (deflated 9%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Result based on 50Coords10ShapeModes_AllRegionsSample4/Shape mode distribution_1_stiff.png (deflated 9%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/50Coords10ShapeModes_AllRegionsSample4.pickle (deflated 4%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/steep1_boundary_coordinate_stack.pickle (deflated 89%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet stiff.csv (deflated 59%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/soft_boundary_coordinate_stack.pickle (deflated 89%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/steep2_boundary_coordinate_stack.pickle (deflated 89%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet steep1.csv (deflated 58%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet soft.csv (deflated 60%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Example model figures/ (stored 0%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Example model figures/Registered objects.png (deflated 4%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/Example model figures/Shape mode dendrogram.png (deflated 9%)
#   adding: content/50Coords10ShapeModes_AllRegionsSample4/VAMPIRE datasheet steep2.csv (deflated 59%)
